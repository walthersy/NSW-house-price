# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.metrics import accuracy_score
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree
# %matplotlib inline

# %%
# Read Data

modelDF = pd.read_csv("Files/Cleaned/Postcode-based/Unstacked_Transformed.csv",
                     index_col="postcode")
modelDF.head()
# Out:
#           mean_price 2020 Q1  mean_price 2020 Q2  mean_price 2020 Q3  \
# postcode
# 2000                  1541.0              1322.0              1631.0
# 2007                   834.0               739.0               658.0
# 2008                   956.0              1144.0               985.0
# 2009                  1277.0              1282.0              1373.0
# 2010                  1357.0              1395.0              1476.0
#
#           mean_price 2020 Q4  mean_price 2021 Q1  median_price 2020 Q1  \
# postcode
# 2000                  1379.0              2794.0                1225.0
# 2007                   677.0               754.0                 745.0
# 2008                  1184.0               937.0                 750.0
# 2009                  1661.0              1427.0                 986.0
# 2010                  2267.0              1371.0                1280.0
#
#           median_price 2020 Q2  median_price 2020 Q3  median_price 2020 Q4  \
# postcode
# 2000                    1000.0                1390.0                1110.0
# 2007                     775.0                 655.0                 651.0
# 2008                    1173.0                 890.0                 991.0
# 2009                    1100.0                1085.0                1075.0
# 2010                    1325.0                1270.0                1240.0
#
#           median_price 2021 Q1  ...  35-54yo_Prop  55-64yo_Prop  65+yo_Prop  \
# postcode                        ...
# 2000                    1371.0  ...      0.229762      0.060924    0.061727
# 2007                     763.0  ...      0.166177      0.037644    0.042957
# 2008                     855.0  ...      0.158982      0.040130    0.031592
# 2009                    1188.0  ...      0.290018      0.095762    0.089753
# 2010                    1201.0  ...      0.322504      0.087802    0.088883
#
#           citizen_AU_Prop  citizen_non_AU_Prop  YARRP <1975_Prop  \
# postcode
# 2000             0.317062             0.534895          0.019153
# 2007             0.308162             0.568958          0.012322
# 2008             0.372097             0.509051          0.013234
# 2009             0.578085             0.323265          0.033560
# 2010             0.604010             0.244222          0.037140
#
#           YARRP 1976-1995_Prop  YARRP 1996-2005_Prop  YARRP 2006-2016_Prop  \
# postcode
# 2000                  0.058006              0.079348              0.475101
# 2007                  0.054149              0.067036              0.510626
# 2008                  0.046192              0.051827              0.471909
# 2009                  0.093733              0.085616              0.291111
# 2010                  0.079436              0.064328              0.226373
#
#           ATSI_Prop
# postcode
# 2000       0.001934
# 2007       0.006557
# 2008       0.006574
# 2009       0.009756
# 2010       0.008474
#
# [5 rows x 121 columns]

# %%
# Remove interest rate, bond yields (they're the same for all postcodes)
# Remove redundant calculated proportion variables
modelDF = modelDF.iloc[:, np.r_[0:56, 96:121]] 

# Drop mean price columns
modelDF = modelDF.drop(["mean_price 2020 Q1", "mean_price 2020 Q2", "mean_price 2020 Q3",
                        "mean_price 2020 Q4", "mean_price 2021 Q1"],
                      axis=1)

# Drop one category from each feature group (optional)
modelDF = modelDF.drop(columns=['INCP_NEG_NIL', 'INCP_NEG_NIL_Prop', 
                                '65+yo','65+yo_Prop',
                                'CPRF_na', 'CPRF_na_Prop',
                                'citizen_AU', 'citizen_AU_Prop'],axis=1)

print(modelDF.shape)
modelDF.head(1)
# Out:
# (573, 68)
#           median_price 2020 Q1  median_price 2020 Q2  median_price 2020 Q3  \
# postcode
# 2000                    1225.0                1000.0                1390.0
#
#           median_price 2020 Q4  median_price 2021 Q1  \
# postcode
# 2000                    1110.0                1371.0
#
#           median_rent_newb 2020 Q1  median_rent_newb 2020 Q2  \
# postcode
# 2000                         700.0                     630.0
#
#           median_rent_newb 2020 Q3  median_rent_newb 2020 Q4  \
# postcode
# 2000                         600.0                     550.0
#
#           median_rent_newb 2021 Q1  ...  15-24yo_Prop  25-34yo_Prop  \
# postcode                            ...
# 2000                         600.0  ...      0.212725      0.389479
#
#           35-54yo_Prop  55-64yo_Prop  citizen_non_AU_Prop  YARRP <1975_Prop  \
# postcode
# 2000          0.229762      0.060924             0.534895          0.019153
#
#           YARRP 1976-1995_Prop  YARRP 1996-2005_Prop  YARRP 2006-2016_Prop  \
# postcode
# 2000                  0.058006              0.079348              0.475101
#
#           ATSI_Prop
# postcode
# 2000       0.001934
#
# [1 rows x 68 columns]

# %%
coord = pd.read_csv("Files/Map Vis/australian_postcodes.csv",
                     index_col="postcode")

# %%
coord = pd.DataFrame(coord)

# %%
coord.head()
# Out:
#            id locality state        long        lat              dc type  \
# postcode
# 1001      458   SYDNEY   NSW  151.268071 -33.794883    EAST SUBS MC  LVR
# 1002      459   SYDNEY   NSW  151.268071 -33.794883    EAST SUBS MC  LVR
# 1003      460   SYDNEY   NSW  151.268071 -33.794883    EAST SUBS MC  LVR
# 1004      461   SYDNEY   NSW  151.268071 -33.794883    EAST SUBS MC  LVR
# 1005      462   SYDNEY   NSW  151.268071 -33.794883  GPO BOX CENTRE  LVR
#
#                            status      sa3            sa3name  ...  \
# postcode                                                       ...
# 1001      Updated 25-Mar-2020 SA3  11703.0  Sydney Inner City  ...
# 1002      Updated 25-Mar-2020 SA3  11703.0  Sydney Inner City  ...
# 1003      Updated 25-Mar-2020 SA3  11703.0  Sydney Inner City  ...
# 1004      Updated 25-Mar-2020 SA3  11703.0  Sydney Inner City  ...
# 1005      Updated 25-Mar-2020 SA3  11703.0  Sydney Inner City  ...
#
#               SA3_NAME_2016 SA4_CODE_2016                  SA4_NAME_2016  \
# postcode
# 1001      Sydney Inner City         117.0  Sydney - City and Inner South
# 1002      Sydney Inner City         117.0  Sydney - City and Inner South
# 1003      Sydney Inner City         117.0  Sydney - City and Inner South
# 1004      Sydney Inner City         117.0  Sydney - City and Inner South
# 1005      Sydney Inner City         117.0  Sydney - City and Inner South
#
#           RA_2011  RA_2016  MMM_2015  MMM_2019  ced altitude  chargezone
# postcode
# 1001          1.0      1.0       1.0       1.0  NaN      NaN          N1
# 1002          1.0      1.0       1.0       1.0  NaN      NaN          N1
# 1003          1.0      1.0       1.0       1.0  NaN      NaN          N1
# 1004          1.0      1.0       1.0       1.0  NaN      NaN          N1
# 1005          1.0      1.0       1.0       1.0  NaN      NaN          N1
#
# [5 rows x 30 columns]

# %% [markdown]
# **INDEX**
#
# id:	Primary Key from source database
#
# postcode:	The postcode in numerical format - 0000 to 9999
#
# locality:	The locality of the postcode - typically the city/suburb or postal distribution centre
#
# state:	The Australian state in which the locality is situated
#
# long:	The longitude of the locality - defaults to 0 when not available
#
# lat:	The latitude of the locality - defaults to 0 when not available
#
# dc1:	The Australia Post distribution Centre servicing this postcode - defaults to blank when not available
#
# type1:	The type of locality, such as a delivery area, post office or a "Large Volume Recipient" such as a GPO, defaults to blank when not available
#
# SA3:	The SA3 Statistical Area code
#
# SA3 Name:	The name of the SA3 Statistical Area
#
# SA4:	The SA4 Statistical Area code
#
# SA4 Name:	The name of the SA4 Statistical Area
#
# Region:	Designated Regional Area
#
# status:	A note indicating whether the data is new, removed or updated - new column Nov 2018
#
# CED:	The Commonwealth Electroal Division
#
# Altitude:	Altitude/Elevation (meters)
#
# Charge Zone:	Australia Post Charge Zones
#
# SA1 Maincode 2011:	Statistical Area 1 2011 Code
#
# SA1 Maincode 2016:	Statistical Area 1 2016 Code
#
# SA2 Maincode 2016:	Statistical Area 2 2016 Code
#
# SA2 Name: 2016	Statistical Area 2 2016 Name
#
# RA 2011	Remoteness Area - 2011 Dataset
#
# RA 2016	Remoteness Area - 2016 Dataset
#
# MMM 2015	Modified Monash Model - 2015 Dataset **(originally was 2016, not 2015)**
#
# MMM 2019	Modified Monash Model - 2019 Dataset

# %%
set(coord['state'])
# Out:
# {'NSW'}

# %%
coord[['id', 'locality']]
# Out:
#              id     locality
# postcode
# 1001        458       SYDNEY
# 1002        459       SYDNEY
# 1003        460       SYDNEY
# 1004        461       SYDNEY
# 1005        462       SYDNEY
# ...         ...          ...
# 4380      21116   RUBY CREEK
# 4380      21122  UNDERCLIFFE
# 4383      21127     JENNINGS
# 4385      21128   CAMP CREEK
# 4385      22877        TEXAS
#
# [5571 rows x 2 columns]

# %%
coord.columns
# Out:
# Index(['id', 'locality', 'state', 'long', 'lat', 'dc', 'type', 'status', 'sa3',
#        'sa3name', 'sa4', 'sa4name', 'region', 'Lat_precise', 'Long_precise',
#        'SA1_MAINCODE_2011', 'SA1_MAINCODE_2016', 'SA2_MAINCODE_2016',
#        'SA2_NAME_2016', 'SA3_CODE_2016', 'SA3_NAME_2016', 'SA4_CODE_2016',
#        'SA4_NAME_2016', 'RA_2011', 'RA_2016', 'MMM_2015', 'MMM_2019', 'ced',
#        'altitude', 'chargezone'],
#       dtype='object')

# %%
coord['region']
# Out:
# postcode
# 1001     R1
# 1002     R1
# 1003     R1
# 1004     R1
# 1005     R1
#        ...
# 4380     R3
# 4380     R3
# 4383     R3
# 4385     R3
# 4385    NaN
# Name: region, Length: 5571, dtype: object

# %%
coord = coord[['id', 'long', 'lat']]

# %%
coord[coord.columns[0:5]]
# Out:
#              id     locality state        long        lat
# postcode
# 1001        458       SYDNEY   NSW  151.268071 -33.794883
# 1002        459       SYDNEY   NSW  151.268071 -33.794883
# 1003        460       SYDNEY   NSW  151.268071 -33.794883
# 1004        461       SYDNEY   NSW  151.268071 -33.794883
# 1005        462       SYDNEY   NSW  151.268071 -33.794883
# ...         ...          ...   ...         ...        ...
# 4380      21116   RUBY CREEK   NSW  152.018346 -28.625911
# 4380      21122  UNDERCLIFFE   NSW  152.182263 -28.622551
# 4383      21127     JENNINGS   NSW  151.969412 -28.940512
# 4385      21128   CAMP CREEK   NSW  150.880359 -28.755116
# 4385      22877        TEXAS   NSW  151.071000 -28.842700
#
# [5571 rows x 5 columns]

# %%
coord[(coord.index >=2000) & (coord.index <= 2880)]
# Out:
#              id           locality state        long        lat  \
# postcode
# 2000      20208         BARANGAROO   NSW  151.201580 -33.860520
# 2000       4478    DARLING HARBOUR   NSW  151.256649 -33.859953
# 2000       4479        DAWES POINT   NSW  151.256649 -33.859953
# 2000       4480          HAYMARKET   NSW  151.256649 -33.859953
# 2000       4481      MILLERS POINT   NSW  151.256649 -33.859953
# ...         ...                ...   ...         ...        ...
# 2880      20747         PACKSADDLE   NSW  142.170513 -30.441973
# 2880       4986          SILVERTON   NSW  142.203381 -30.170441
# 2880       4987  SOUTH BROKEN HILL   NSW  142.203381 -30.170441
# 2880       4988     STEPHENS CREEK   NSW  142.203381 -30.170441
# 2880       4989         TIBOOBURRA   NSW  142.203381 -30.170441
#
#                                   dc           type              status  \
# postcode
# 2000                    Sydney Metro  Delivery Area  Updated 6-Feb-2020
# 2000                    Sydney Metro            NaN  Updated 6-Feb-2020
# 2000      WATERLOO DELIVERY FACILITY  Delivery Area  Updated 6-Feb-2020
# 2000      WATERLOO DELIVERY FACILITY  Delivery Area  Updated 6-Feb-2020
# 2000      WATERLOO DELIVERY FACILITY  Delivery Area  Updated 6-Feb-2020
# ...                              ...            ...                 ...
# 2880                     Broken Hill  Delivery Area  Updated 6-Feb-2020
# 2880            BROKEN HILL DELIVERY  Delivery Area  Updated 6-Feb-2020
# 2880           BROKEN HILL SOUTH LPO  Delivery Area  Updated 6-Feb-2020
# 2880            BROKEN HILL DELIVERY  Delivery Area  Updated 6-Feb-2020
# 2880            BROKEN HILL DELIVERY  Delivery Area  Updated 6-Feb-2020
#
#               sa3                   sa3name  ...             SA3_NAME_2016  \
# postcode                                     ...
# 2000      11703.0         Sydney Inner City  ...         Sydney Inner City
# 2000      11703.0         Sydney Inner City  ...         Sydney Inner City
# 2000      11703.0         Sydney Inner City  ...         Sydney Inner City
# 2000      11703.0         Sydney Inner City  ...         Sydney Inner City
# 2000      11703.0         Sydney Inner City  ...         Sydney Inner City
# ...           ...                       ...  ...                       ...
# 2880      10502.0  Broken Hill and Far West  ...  Broken Hill and Far West
# 2880      10502.0  Broken Hill and Far West  ...  Broken Hill and Far West
# 2880      10502.0  Broken Hill and Far West  ...  Broken Hill and Far West
# 2880      10502.0  Broken Hill and Far West  ...  Broken Hill and Far West
# 2880      10502.0  Broken Hill and Far West  ...  Broken Hill and Far West
#
#          SA4_CODE_2016                  SA4_NAME_2016  RA_2011  RA_2016  \
# postcode
# 2000             117.0  Sydney - City and Inner South      1.0      1.0
# 2000             117.0  Sydney - City and Inner South      1.0      1.0
# 2000             117.0  Sydney - City and Inner South      1.0      1.0
# 2000             117.0  Sydney - City and Inner South      1.0      1.0
# 2000             117.0  Sydney - City and Inner South      1.0      1.0
# ...                ...                            ...      ...      ...
# 2880             105.0             Far West and Orana      4.0      4.0
# 2880             105.0             Far West and Orana      4.0      4.0
# 2880             105.0             Far West and Orana      3.0      3.0
# 2880             105.0             Far West and Orana      4.0      4.0
# 2880             105.0             Far West and Orana      5.0      5.0
#
#           MMM_2015  MMM_2019     ced    altitude  chargezone
# postcode
# 2000           1.0       1.0  Sydney         NaN          N1
# 2000           1.0       1.0  Sydney         NaN          N1
# 2000           1.0       1.0  Sydney         NaN          N1
# 2000           1.0       1.0  Sydney         NaN          N1
# 2000           1.0       1.0  Sydney         NaN          N1
# ...            ...       ...     ...         ...         ...
# 2880           6.0       6.0  Parkes  192.477799          S2
# 2880           6.0       6.0  Parkes  192.477799          S2
# 2880           3.0       3.0  Parkes  192.477799          S2
# 2880           6.0       6.0  Parkes  192.477799          S2
# 2880           7.0       7.0  Parkes  192.477799          S2
#
# [5282 rows x 30 columns]
